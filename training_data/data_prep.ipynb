# %% [markdown]
# # Judging an Album by its Cover

# %% [markdown]
# ### hive query
#
# `hive -S -e '
#     SELECT musicapi_album.art_url, analytics_d_genre.genre
#     FROM ( analytics_d_genre
#         INNER JOIN musicapi_album ON analytics_d_genre.uid = musicapi_album.album_uid)
#     WHERE NOT ( analytics_d_genre.genre = "Unknown" );
# ' > album_art_dataset.tsv`

# %%
import csv
import os
import urllib
import urllib.request
import ssl
import multiprocessing
import glob
import math

# %% [markdown]
# ### get the [url, genre] tsv into python

# %%
url_data = []

with open('album_art_dataset.tsv') as tsv:
    count = 0
    for row in csv.reader(tsv, delimiter='\t'):
        url_data.append(row)

print('%s rows ingested' %len(url_data))
# Out:
# 483967 rows ingested

# %% [markdown]
# ### helper functions

# %%
def get_filepath_from_url(url):
    # deprecated
    return os.path.join('data', get_filename_from_url(url))

def get_filepath_from_row(row):
    return os.path.join('data', row[1], get_filename_from_url(row[0]))

def get_filename_from_url(url):
    return urllib.parse.quote_plus(url) + '.jpg'

def get_url_from_filepath(filepath):
    stripped = filepath
    if stripped[:5] == 'data/':
        stripped = stripped[5:]
    if stripped[4:] == '.jpg':
        stripped = stripped[:-4]
    parts = stripped.split('/')
    return urllib.parse.unquote_plus(parts[-1])

# %% [markdown]
# ### download all of the images

# %%
ssl._create_default_https_context = ssl._create_unverified_context # never do this

def maybe_download(url):
    filepath = get_filepath_from_url(url)
    if os.path.exists(filepath):
        return
    print('requesting %s' % url)
    urllib.request.urlretrieve(url, filepath)

def process_row(row):
    maybe_download(row[0])
    
# sweet multithreaded downloading action
# pool = multiprocessing.Pool(processes=25)
# pool.map(process_row, url_data)
sum([len(files) for r, d, files in os.walk("data")])
print('%s rows in dataset, %s files present' % (len(url_data), sum([len(files) for r, d, files in os.walk("data")])))
# Out:
# 483967 rows in dataset, 478876 files present

# %% [markdown]
# ### sanity checking after download complete

# %%
print(len(url_data))
filepath = get_filepath_from_row(url_data[10])
print('file path %s exists: %s' % (filepath, os.path.exists(filepath)))
print(get_url_from_filepath(filepath))
# Out:
# 483967
# file path data/RAP/https%3A%2F%2Fdyn-images.p-cdn.com%2F%3Fl%3Dimages%2Fpublic%2Fint%2F8%2F1%2F3%2F1%2F888002121318%26w%3D256.jpg exists: True
# https://dyn-images.p-cdn.com/?l=images/public/int/8/1/3/1/888002121318&w=256.jpg

# %% [markdown]
# ### regretting using the file system as database
# #### very slow renaming/moving to more managably sized directories

# %%
file_list = os.listdir("data")
renamed_count = 0
total_count = 0
for filename in file_list:
    total_count = total_count + 1
    if not filename.endswith(".jpg") and filename != '.DS_Store':
        renamed_count = renamed_count + 1
        if renamed_count % 1000 == 0:
            print('%s files renamed' % renamed_count)
        os.rename('data/'+filename, 'data/'+filename+'.jpg')
    if total_count % 10000 == 0:
        print('%s files processed out of %s' % (total_count, len(file_list)))
# Out:
# 10000 files processed out of 592800
# 20000 files processed out of 592800
# 30000 files processed out of 592800
# 40000 files processed out of 592800
# 1000 files renamed
# 2000 files renamed
# 3000 files renamed
# 4000 files renamed
# 5000 files renamed
# 6000 files renamed
# 7000 files renamed
# 50000 files processed out of 592800
# 8000 files renamed
# 9000 files renamed
# 10000 files renamed
# 11000 files renamed
# 12000 files renamed
# 13000 files renamed
# 60000 files processed out of 592800
# 14000 files renamed
# 15000 files renamed
# 16000 files renamed
# 17000 files renamed
# 18000 files renamed
# 19000 files renamed
# 20000 files renamed
# 70000 files processed out of 592800
# 21000 files renamed
# 22000 files renamed
# 23000 files renamed
# 24000 files renamed
# 25000 files renamed
# 26000 files renamed
# 27000 files renamed
# 80000 files processed out of 592800
# 28000 files renamed
# 29000 files renamed
# 30000 files renamed
# 31000 files renamed
# 32000 files renamed
# 33000 files renamed
# 90000 files processed out of 592800
# 34000 files renamed
# 35000 files renamed
# 36000 files renamed
# 37000 files renamed
# 38000 files renamed
# 39000 files renamed
# 40000 files renamed
# 100000 files processed out of 592800
# 41000 files renamed
# 42000 files renamed
# 43000 files renamed
# 44000 files renamed
# 45000 files renamed
# 46000 files renamed
# 110000 files processed out of 592800
# 47000 files renamed
# 48000 files renamed
# 49000 files renamed
# 50000 files renamed
# 51000 files renamed
# 52000 files renamed
# 120000 files processed out of 592800
# 53000 files renamed
# 54000 files renamed
# 55000 files renamed
# 56000 files renamed
# 57000 files renamed
# 58000 files renamed
# 59000 files renamed
# 130000 files processed out of 592800
# 60000 files renamed
# 61000 files renamed
# 62000 files renamed
# 63000 files renamed
# 64000 files renamed
# 65000 files renamed
# 140000 files processed out of 592800
# 66000 files renamed
# 67000 files renamed
# 68000 files renamed
# 69000 files renamed
# 70000 files renamed
# 71000 files renamed
# 72000 files renamed
# 73000 files renamed
# 74000 files renamed
# 150000 files processed out of 592800
# 75000 files renamed
# 76000 files renamed
# 77000 files renamed
# 78000 files renamed
# 79000 files renamed
# 80000 files renamed
# 81000 files renamed
# 82000 files renamed
# 160000 files processed out of 592800
# 83000 files renamed
# 84000 files renamed
# 85000 files renamed
# 86000 files renamed
# 87000 files renamed
# 88000 files renamed
# 89000 files renamed
# 90000 files renamed
# 170000 files processed out of 592800
# 91000 files renamed
# 92000 files renamed
# 93000 files renamed
# 94000 files renamed
# 95000 files renamed
# 96000 files renamed
# 97000 files renamed
# 98000 files renamed
# 99000 files renamed
# 180000 files processed out of 592800
# 100000 files renamed
# 101000 files renamed
# 102000 files renamed
# 103000 files renamed
# 104000 files renamed
# 105000 files renamed
# 106000 files renamed
# 107000 files renamed
# 190000 files processed out of 592800
# 108000 files renamed
# 109000 files renamed
# 110000 files renamed
# 111000 files renamed
# 112000 files renamed
# 113000 files renamed
# 114000 files renamed
# 115000 files renamed
# 116000 files renamed
# 200000 files processed out of 592800
# 117000 files renamed
# 118000 files renamed
# 119000 files renamed
# 120000 files renamed
# 121000 files renamed
# 122000 files renamed
# 123000 files renamed
# 124000 files renamed
# 210000 files processed out of 592800
# 125000 files renamed
# 126000 files renamed
# 127000 files renamed
# 128000 files renamed
# 129000 files renamed
# 130000 files renamed
# 131000 files renamed
# 132000 files renamed
# 133000 files renamed
# 220000 files processed out of 592800
# 134000 files renamed
# 135000 files renamed
# 136000 files renamed
# 137000 files renamed
# 138000 files renamed
# 139000 files renamed
# 140000 files renamed
# 141000 files renamed
# 230000 files processed out of 592800
# 142000 files renamed
# 143000 files renamed
# 144000 files renamed
# 145000 files renamed
# 146000 files renamed
# 147000 files renamed
# 148000 files renamed
# 149000 files renamed
# 150000 files renamed
# 240000 files processed out of 592800
# 151000 files renamed
# 152000 files renamed
# 153000 files renamed
# 154000 files renamed
# 155000 files renamed
# 156000 files renamed
# 157000 files renamed
# 158000 files renamed
# 250000 files processed out of 592800
# 159000 files renamed
# 160000 files renamed
# 161000 files renamed
# 162000 files renamed
# 163000 files renamed
# 164000 files renamed
# 165000 files renamed
# 166000 files renamed
# 260000 files processed out of 592800
# 167000 files renamed
# 168000 files renamed
# 169000 files renamed
# 170000 files renamed
# 171000 files renamed
# 172000 files renamed
# 173000 files renamed
# 174000 files renamed
# 175000 files renamed
# 270000 files processed out of 592800
# 176000 files renamed
# 177000 files renamed
# 178000 files renamed
# 179000 files renamed
# 180000 files renamed
# 181000 files renamed
# 182000 files renamed
# 183000 files renamed
# 280000 files processed out of 592800
# 184000 files renamed
# 185000 files renamed
# 186000 files renamed
# 187000 files renamed
# 188000 files renamed
# 189000 files renamed
# 190000 files renamed
# 191000 files renamed
# 192000 files renamed
# 290000 files processed out of 592800
# 193000 files renamed
# 194000 files renamed
# 195000 files renamed
# 196000 files renamed
# 197000 files renamed
# 198000 files renamed
# 199000 files renamed
# 200000 files renamed
# 300000 files processed out of 592800
# 201000 files renamed
# 202000 files renamed
# 203000 files renamed
# 204000 files renamed
# 205000 files renamed
# 206000 files renamed
# 207000 files renamed
# 208000 files renamed
# 209000 files renamed
# 310000 files processed out of 592800
# 210000 files renamed
# 211000 files renamed
# 212000 files renamed
# 213000 files renamed
# 214000 files renamed
# 215000 files renamed
# 216000 files renamed
# 217000 files renamed
# 320000 files processed out of 592800
# 218000 files renamed
# 219000 files renamed
# 220000 files renamed
# 221000 files renamed
# 222000 files renamed
# 223000 files renamed
# 224000 files renamed
# 225000 files renamed
# 226000 files renamed
# 330000 files processed out of 592800
# 227000 files renamed
# 228000 files renamed
# 229000 files renamed
# 230000 files renamed
# 231000 files renamed
# 232000 files renamed
# 233000 files renamed
# 234000 files renamed
# 340000 files processed out of 592800
# 235000 files renamed
# 236000 files renamed
# 237000 files renamed
# 238000 files renamed
# 239000 files renamed
# 240000 files renamed
# 241000 files renamed
# 242000 files renamed
# 243000 files renamed
# 350000 files processed out of 592800
# 244000 files renamed
# 245000 files renamed
# 246000 files renamed
# 247000 files renamed
# 248000 files renamed
# 249000 files renamed
# 250000 files renamed
# 251000 files renamed
# 360000 files processed out of 592800
# 252000 files renamed
# 253000 files renamed
# 254000 files renamed
# 255000 files renamed
# 256000 files renamed
# 257000 files renamed
# 258000 files renamed
# 259000 files renamed
# 370000 files processed out of 592800
# 260000 files renamed
# 261000 files renamed
# 262000 files renamed
# 263000 files renamed
# 264000 files renamed
# 265000 files renamed
# 266000 files renamed
# 267000 files renamed
# 268000 files renamed
# 380000 files processed out of 592800
# 269000 files renamed
# 270000 files renamed
# 271000 files renamed
# 272000 files renamed
# 273000 files renamed
# 274000 files renamed
# 275000 files renamed
# 276000 files renamed
# 390000 files processed out of 592800
# 277000 files renamed
# 278000 files renamed
# 279000 files renamed
# 280000 files renamed
# 281000 files renamed
# 282000 files renamed
# 283000 files renamed
# 284000 files renamed
# 285000 files renamed
# 400000 files processed out of 592800
# 286000 files renamed
# 287000 files renamed
# 288000 files renamed
# 289000 files renamed
# 290000 files renamed
# 291000 files renamed
# 292000 files renamed
# 293000 files renamed
# 410000 files processed out of 592800
# 294000 files renamed
# 295000 files renamed
# 296000 files renamed
# 297000 files renamed
# 298000 files renamed
# 299000 files renamed
# 300000 files renamed
# 301000 files renamed
# 302000 files renamed
# 420000 files processed out of 592800
# 303000 files renamed
# 304000 files renamed
# 305000 files renamed
# 306000 files renamed
# 307000 files renamed
# 308000 files renamed
# 309000 files renamed
# 310000 files renamed
# 430000 files processed out of 592800
# 311000 files renamed
# 312000 files renamed
# 313000 files renamed
# 314000 files renamed
# 315000 files renamed
# 316000 files renamed
# 317000 files renamed
# 318000 files renamed
# 319000 files renamed
# 440000 files processed out of 592800
# 320000 files renamed
# 321000 files renamed
# 322000 files renamed
# 323000 files renamed
# 324000 files renamed
# 325000 files renamed
# 326000 files renamed
# 327000 files renamed
# 450000 files processed out of 592800
# 328000 files renamed
# 329000 files renamed
# 330000 files renamed
# 331000 files renamed
# 332000 files renamed
# 333000 files renamed
# 334000 files renamed
# 335000 files renamed
# 336000 files renamed
# 460000 files processed out of 592800
# 337000 files renamed
# 338000 files renamed
# 339000 files renamed
# 340000 files renamed
# 341000 files renamed
# 342000 files renamed
# 343000 files renamed
# 344000 files renamed
# 470000 files processed out of 592800
# 345000 files renamed
# 346000 files renamed
# 347000 files renamed
# 348000 files renamed
# 349000 files renamed
# 350000 files renamed
# 351000 files renamed
# 352000 files renamed
# 353000 files renamed
# 480000 files processed out of 592800
# 354000 files renamed
# 355000 files renamed
# 356000 files renamed
# 357000 files renamed
# 358000 files renamed
# 359000 files renamed
# 360000 files renamed
# 361000 files renamed
# 490000 files processed out of 592800
# 362000 files renamed
# 363000 files renamed
# 364000 files renamed
# 365000 files renamed
# 366000 files renamed
# 367000 files renamed
# 368000 files renamed
# 369000 files renamed
# 500000 files processed out of 592800
# 370000 files renamed
# 371000 files renamed
# 372000 files renamed
# 373000 files renamed
# 374000 files renamed
# 375000 files renamed
# 376000 files renamed
# 377000 files renamed
# 378000 files renamed
# 510000 files processed out of 592800
# 379000 files renamed
# 380000 files renamed
# 381000 files renamed
# 382000 files renamed
# 383000 files renamed
# 384000 files renamed
# 385000 files renamed
# 520000 files processed out of 592800
# 386000 files renamed
# 387000 files renamed
# 388000 files renamed
# 389000 files renamed
# 390000 files renamed
# 391000 files renamed
# 392000 files renamed
# 530000 files processed out of 592800
# 393000 files renamed
# 394000 files renamed
# 395000 files renamed
# 396000 files renamed
# 397000 files renamed
# 398000 files renamed
# 399000 files renamed
# 400000 files renamed
# 540000 files processed out of 592800
# 401000 files renamed
# 402000 files renamed
# 403000 files renamed
# 404000 files renamed
# 405000 files renamed
# 406000 files renamed
# 407000 files renamed
# 550000 files processed out of 592800
# 408000 files renamed
# 409000 files renamed
# 410000 files renamed
# 411000 files renamed
# 412000 files renamed
# 413000 files renamed
# 414000 files renamed
# 415000 files renamed
# 560000 files processed out of 592800
# 416000 files renamed
# 417000 files renamed
# 418000 files renamed
# 419000 files renamed
# 420000 files renamed
# 421000 files renamed
# 422000 files renamed
# 570000 files processed out of 592800
# 423000 files renamed
# 424000 files renamed
# 425000 files renamed
# 426000 files renamed
# 427000 files renamed
# 428000 files renamed
# 429000 files renamed
# 580000 files processed out of 592800
# 430000 files renamed
# 431000 files renamed
# 432000 files renamed
# 433000 files renamed
# 434000 files renamed
# 435000 files renamed
# 436000 files renamed
# 437000 files renamed
# 590000 files processed out of 592800
# 438000 files renamed
# 439000 files renamed

# %%
moved_count = 0
total_count = 0
for row in url_data:
    filepath = get_filepath_from_url(row[0])
    target_directory = os.path.join('data', row[1])
    if not os.path.exists(target_directory):
        os.makedirs(target_directory)
    target_path = os.path.join(target_directory, get_filename_from_url(row[0]))
    
    if os.path.exists(filepath):
        os.rename(filepath, target_path)
        moved_count = moved_count + 1
        if moved_count % 1000 == 0:
            print('%s files moved' % moved_count)
        
    total_count = total_count + 1
    if total_count % 10000 == 0:
        print('%s files processed out of %s' % (total_count, len(url_data)))
# Out:
# 10000 files processed out of 483967
# 20000 files processed out of 483967
# 30000 files processed out of 483967
# 40000 files processed out of 483967
# 50000 files processed out of 483967
# 60000 files processed out of 483967
# 70000 files processed out of 483967
# 80000 files processed out of 483967
# 90000 files processed out of 483967
# 100000 files processed out of 483967
# 110000 files processed out of 483967
# 120000 files processed out of 483967
# 130000 files processed out of 483967
# 140000 files processed out of 483967
# 150000 files processed out of 483967
# 160000 files processed out of 483967
# 170000 files processed out of 483967
# 180000 files processed out of 483967
# 190000 files processed out of 483967
# 200000 files processed out of 483967
# 210000 files processed out of 483967
# 220000 files processed out of 483967
# 230000 files processed out of 483967
# 240000 files processed out of 483967
# 250000 files processed out of 483967
# 260000 files processed out of 483967
# 270000 files processed out of 483967
# 280000 files processed out of 483967
# 290000 files processed out of 483967
# 300000 files processed out of 483967
# 310000 files processed out of 483967
# 320000 files processed out of 483967
# 330000 files processed out of 483967
# 340000 files processed out of 483967
# 350000 files processed out of 483967
# 360000 files processed out of 483967
# 1000 files moved
# 2000 files moved
# 3000 files moved
# 4000 files moved
# 5000 files moved
# 6000 files moved
# 7000 files moved
# 8000 files moved
# 9000 files moved
# 10000 files moved
# 370000 files processed out of 483967
# 11000 files moved
# 12000 files moved
# 13000 files moved
# 14000 files moved
# 15000 files moved
# 16000 files moved
# 17000 files moved
# 18000 files moved
# 19000 files moved
# 20000 files moved
# 380000 files processed out of 483967
# 21000 files moved
# 22000 files moved
# 23000 files moved
# 24000 files moved
# 25000 files moved
# 26000 files moved
# 27000 files moved
# 28000 files moved
# 29000 files moved
# 30000 files moved
# 390000 files processed out of 483967
# 31000 files moved
# 32000 files moved
# 33000 files moved
# 34000 files moved
# 35000 files moved
# 36000 files moved
# 37000 files moved
# 38000 files moved
# 39000 files moved
# 40000 files moved
# 400000 files processed out of 483967
# 41000 files moved
# 42000 files moved
# 43000 files moved
# 44000 files moved
# 45000 files moved
# 46000 files moved
# 47000 files moved
# 48000 files moved
# 49000 files moved
# 50000 files moved
# 410000 files processed out of 483967
# 51000 files moved
# 52000 files moved
# 53000 files moved
# 54000 files moved
# 55000 files moved
# 56000 files moved
# 57000 files moved
# 58000 files moved
# 59000 files moved
# 60000 files moved
# 420000 files processed out of 483967
# 61000 files moved
# 62000 files moved
# 63000 files moved
# 64000 files moved
# 65000 files moved
# 66000 files moved
# 67000 files moved
# 68000 files moved
# 69000 files moved
# 70000 files moved
# 430000 files processed out of 483967
# 71000 files moved
# 72000 files moved
# 73000 files moved
# 74000 files moved
# 75000 files moved
# 76000 files moved
# 77000 files moved
# 78000 files moved
# 79000 files moved
# 440000 files processed out of 483967
# 80000 files moved
# 81000 files moved
# 82000 files moved
# 83000 files moved
# 84000 files moved
# 85000 files moved
# 86000 files moved
# 87000 files moved
# 88000 files moved
# 89000 files moved
# 450000 files processed out of 483967
# 90000 files moved
# 91000 files moved
# 92000 files moved
# 93000 files moved
# 94000 files moved
# 95000 files moved
# 96000 files moved
# 97000 files moved
# 98000 files moved
# 99000 files moved
# 460000 files processed out of 483967
# 100000 files moved
# 101000 files moved
# 102000 files moved
# 103000 files moved
# 104000 files moved
# 105000 files moved
# 106000 files moved
# 107000 files moved
# 108000 files moved
# 109000 files moved
# 470000 files processed out of 483967
# 110000 files moved
# 111000 files moved
# 112000 files moved
# 113000 files moved
# 114000 files moved
# 115000 files moved
# 116000 files moved
# 117000 files moved
# 118000 files moved
# 119000 files moved
# 480000 files processed out of 483967
# 120000 files moved
# 121000 files moved
# 122000 files moved
# 123000 files moved

# %%
paths = []
file_count = 0
for root, dirs, files in os.walk('data'):
    print(root)
    file_count += len(files)
    paths.append([root, len(files)])
paths = paths[1:]

print(paths)
print(file_count)
# Out:
# data
# data/BLUES
# data/CHILD
# data/CLASS
# data/CTRY
# data/ELEC
# data/FOLK
# data/HOLID
# data/JAZZ
# data/LATIN
# data/NUAGE
# data/R&B
# data/RAP
# data/REGG
# data/ROCK
# data/SPOKN
# [['data/BLUES', 5513], ['data/CHILD', 2363], ['data/CLASS', 20166], ['data/CTRY', 19572], ['data/ELEC', 57346], ['data/FOLK', 21396], ['data/HOLID', 4658], ['data/JAZZ', 31697], ['data/LATIN', 29833], ['data/NUAGE', 9278], ['data/R&B', 34413], ['data/RAP', 44412], ['data/REGG', 14434], ['data/ROCK', 179222], ['data/SPOKN', 4572]]
# 478876

# %% [markdown]
# ### pull out a subset of images to train on

# %%
stage_path = 'stage'
def stage_data(proportion=0.25):
    if not os.path.exists(stage_path):
        os.makedirs(stage_path)
        
    for (path, file_count) in paths:
        category_name = path.split('/')[1]
        category_stage_path = os.path.join(stage_path, category_name)
        print(category_stage_path)
        if not os.path.exists(category_stage_path):
            os.makedirs(category_stage_path)
        
        already_staged_files = os.listdir(category_stage_path)
        
        number_to_process = math.floor(file_count * proportion) - len(already_staged_files)
        
        print(path, file_count, number_to_process)
        
        unstaged_files = os.listdir(path)
        print(len(unstaged_files))
        
        for i in range(number_to_process):
            os.rename(os.path.join(path, unstaged_files[i]), os.path.join(category_stage_path, unstaged_files[i]))
            
stage_data()
# Out:
# stage/BLUES
# data/BLUES 5513 552
# 4687
# stage/CHILD
# data/CHILD 2363 236
# 2009
# stage/CLASS
# data/CLASS 20166 2017
# 17142
# stage/CTRY
# data/CTRY 19572 1958
# 16637
# stage/ELEC
# data/ELEC 57346 5735
# 48745
# stage/FOLK
# data/FOLK 21396 2140
# 18187
# stage/HOLID
# data/HOLID 4658 466
# 3960
# stage/JAZZ
# data/JAZZ 31697 3170
# 26943
# stage/LATIN
# data/LATIN 29833 2984
# 25359
# stage/NUAGE
# data/NUAGE 9278 928
# 7887
# stage/R&B
# data/R&B 34413 3442
# 29252
# stage/RAP
# data/RAP 44412 4442
# 37751
# stage/REGG
# data/REGG 14434 1443
# 12269
# stage/ROCK
# data/ROCK 179222 17922
# 152339
# stage/SPOKN
# data/SPOKN 4572 458
# 3887
